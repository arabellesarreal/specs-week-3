# %% [markdown]
# # Unit 3 Project - Exploratory Data Analysis

# %% [markdown]
# ## Part 1 - Univariate Analysis - Visualization

# %% [markdown]
# ### Step 1 - Open Jupyter Notebook in New Virtual Environment

# %% [markdown]
# ###### This step should have been completed prior to opening the Jupyter Notebook. If it was not, create and activate your virtual environment, then restart your notebook within the venv.

# %% [markdown]
# ### Step 2 - Load DataFrame and Explore Dataset

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# import pandas and numpy
import pandas as pd
import numpy as np

# %%
# load salary.csv into dataframe
df = pandas.read_csv("salary.csv")

# %%
# look at first few values of dataframe
df.head()
# Out:
#    age gender    education  industry  industry_experience       salary
# 0   19   Male  high school  business                    0  33640.60752
# 1   21   Male  high school  business                    2  43554.24216
# 2   19   Male  high school  business                    0  39795.29424
# 3   22   Male  high school  business                    1  51102.98856
# 4   21   Male  high school  business                    1  32809.57056

# %%
# look at basic dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25439 entries, 0 to 25438
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  25439 non-null  int64
#  1   gender               25439 non-null  object
#  2   education            25439 non-null  object
#  3   industry             25439 non-null  object
#  4   industry_experience  25439 non-null  int64
#  5   salary               25439 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Step 3 - Review Types of Basic Univariate Plots

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with a brief description of each plot type:
#
#
# - Histogram
# > Histogram groups numbers into ranges. Looks similar to a barchart. Can be useful for showing skew.
# - Density Plot / KDE
# > Used for visualizing distribution of observations in a dataset.
# - Bar Chart
# > Useful for visualizing the count of nominal/categorical data. Fixes the visual problems with pie charts.
# - Line Plot
# > Displays numerical data using a series of points connected by straight lines
# - Univariate scatter plot
# > Aligns points along a vertical and horizontal axis based on two variables. Determine a relationship between the plotted variables.
# - Violin Plot
# > representing the density of the data at different values
# - Box Plot
# > used to show the spread of data within a specified range. Plotly allows you to add elements that help to make data insights more intersectional
# - Pie Chart
# > visualize value distribution for nominal or ordinal data
# - Rug Plot
# > displays the distribution of numerical data by placing a tick mark or line for each observation on a number line. The tick marks or lines are plotted vertically above the number line at the value of each observation

# %% [markdown]
# ### Step 4 - Choose Which Plot(s) You Will Use for Each Variable

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Take a moment to plan what types of plots you will make for each variable
#
#
# - age
# > Violin Plot...
# - gender
# > Pie Chart...
# - education
# > Scatter Plot...
# - industry
# > Count Plot...
# - industry experience
# > Histogram...
# - salary
# > Histogram Model...

# %% [markdown]
# ### Step 5 - Create Plots for Each Variable in Dataset

# %%
# import seaborn
import seaborn as sns

# set standard plot type as seaborn plot
sns.set()

# import matplotlib
import matplotlib.pyplot as plt

# write command for plots to appear in jupyter cells automatically
# %matplotlib inline

sns.set()

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Plot for 'age' column

# %%
# create plot for age column
plt.figure(figsize =(12,6))

sns.violinplot(x=df['age'])

plt.xlabel("Age", fontsize = 14)
plt.ylabel("Number of Managers", fontsize = 14)
# Out:
# Text(0, 0.5, 'Number of Managers')

# %% [markdown]
# ##### Insights:
#
# The older you are the more managers you have because of the longer you have to gain experience and time for managers to change.

# %% [markdown]
# ### Plot for 'industry' column

# %%
plt.figure(figsize=(12,6))

ax = sns.countplot(data=df, x='industry',palette="icefire")

plt.xticks(rotation=90)
plt.xlabel("Industry", fontsize=13)
plt.ylabel("Number of Managers in Industry", fontsize=13)
plt.title("Industries in Survey", fontsize=15);

# %% [markdown]
# ##### Insights:
#
# It is hard to gain insight from this graph as all the heights of the bars are only slightly different from one another.

# %% [markdown]
# ### Plot for 'salary' column

# %%
sns.displot(data = df, x = 'salary', kind = 'hist', bins=30)

plt.xlabel("Salary", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Distribution of Salary Among Managers", fontsize=14);

# %% [markdown]
# ##### Insights:
#
# According to this chart the average salary is around 100k

# %% [markdown]
# ### Plot for 'industry_experience' column

# %%
plt.figure(figsize=(12,6))

ax = sns.countplot(data=df, x='industry_experience',palette="icefire")

# %% [markdown]
# ##### Insights:
#
# most people have around 15-20 years of experience

# %% [markdown]
# ### Plot for 'education' column

# %%
plt.figure(figsize=(12,6))

ax = sns.countplot(data=df, x='education',palette="icefire")

# %% [markdown]
# ##### Insights:
#
# most people have at least a bachelors degree

# %% [markdown]
# ### Plot for 'gender' column

# %%
plt.figure(figsize=(10,10))

data = df['gender'].value_counts()

labels = ['Male', 'Female']

colors = sns.color_palette('rainbow')

ax = plt.pie(data, colors=colors, labels=labels, autopct='%.0f%%');

# %% [markdown]
# ##### Insights:
#
# There are equal amount of males as there are females

# %% [markdown]
# ## Part 2 - Summary Statistics

# %% [markdown]
# ### Step 1 - Review Summary Statistics

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# - mean
# > Sum of all numbers divided by the amount of numbers/average of all numbers
# - median
# > The middle number in a ordered list of numbers
# - mode
# > The number the occurs the most often within a list of numbers
# - central tendency
# > A number that indicates where the "middle" is
# - distribution
# > A showing of possible values for a variable and how often they occur
# - variance
# > How far apart a set of numbers is spread out
# - standard deviation
# > The average amount of variability in a dataset

# %% [markdown]
# ### Step 2 - Find  & Report Summary Statistics For Numeric Variables

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Age Summary Statistics

# %%
# use .describe to get summary statistics for age column
df['age'].describe()
# Out:
# count    25439.000000
# mean        46.219466
# std         12.758662
# min         18.000000
# 25%         36.000000
# 50%         47.000000
# 75%         57.000000
# max         67.000000
# Name: age, dtype: float64

# %%
# create boxplot to visualize age summary statistics
plt.figure(figsize = (12,4))
plt.title('Age Distribution Among Managers', fontsize = 16)
sns.boxplot(x=df['age'])
plt.xlabel("Manager Age", fontsize = 14);

# %% [markdown]
# - age **mean**
# > The mean age is 46.21
# - age **median**
# > The median age is 47
# - age **minimum**
# > The minimum age is 18
# - age **maximum**
# > The maximum age is 67
# - age **standard deviation**
# > The standard deviation is 12

# %% [markdown]
# ###### Reflection: How did mean and median differ above? Why do you think that is?
#
# Mean takes the average of all numbers together median is just the number in the middle. They differ barely but, if you change the min and max the mean changes but the median does not.

# %% [markdown]
# #### Salary Summary Statistics

# %%
# use .describe to get summary statistics for salary
df['salary'].describe()
# Out:
# count     25439.000000
# mean     101416.000070
# std       26136.687123
# min       28054.080000
# 25%       84621.294048
# 50%      101148.480000
# 75%      119828.075728
# max      175223.321900
# Name: salary, dtype: float64

# %%
# create boxplot to visualize salary summary statistics
plt.figure(figsize = (12,4))
plt.title('Distribution of Salary Among Managers', fontsize = 16)
sns.boxplot(x=df['salary'])
plt.xlabel("Annual Salary(USD)", fontsize = 14);

# %% [markdown]
# - Salary **mean**
# > The mean salary is 101416
# - Salary **median**
# > The median salary is 101148
# - Salary **minimum**
# > The minimum salary is 28054
# - Salary **maximum**
# > The maximum salary is 175223
# - Salary **standard deviation**
# > The standard deviation is 26136

# %% [markdown]
# ###### Reflection: How did mean and median differ above? Why do you think that is?
#
# Mean takes the average of all numbers together median is just the number in the middle. They differ barely but, if you change the min and max the mean changes but the median does not.

# %% [markdown]
# ### Step 3 - Find Salary Summary Statistics By Industry

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by industry
df['salary'].groupby(df['industry']).describe()
# Out:
#              count           mean           std          min           25%  \
# industry
# business    6367.0   98296.471387  24822.138864  29340.67968  82482.816000
# finance     6383.0  102838.541755  26344.729075  30747.52224  86224.406400
# healthcare  6307.0   94767.547447  23696.008298  28054.08000  79538.185000
# technology  6382.0  109675.753478  27127.404233  32704.34400  92223.969112
#
#                      50%            75%           max
# industry
# business     98200.01048  116110.250464  159030.78048
# finance     102692.33568  122237.832000  166370.21852
# healthcare   94728.96000  112058.784000  152775.98600
# technology  109130.17575  129758.177182  175223.32190

# %%
# create visualization with multiple boxplots to show salary summary statistics by industry
plt.figure(figsize=(12,8))
ax = sns.boxplot(data=df, x = 'industry', y = 'salary')
plt.xlabel("Industry", fontsize = 14)
plt.ylabel("Salary", fontsize = 14)
plt.title("Distribution of Salaries Across Industries", fontsize = 16);

# %% [markdown]
# ##### Insights:
#
# Technology has the highest salary on average and healthcare has the lowest on average. There are a few outliers towards the bottom.

# %% [markdown]
# ### Step 4 - Find Salary Summary Statistics By Education

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by education level
df['salary']. groupby(df['education']).describe()
# Out:
#                     count           mean           std        min  \
# education
# bachelors degree  10972.0  100710.905311  20960.707146  40962.240
# high school         781.0   47602.924607  10556.975508  28054.080
# masters degree     8979.0  115583.500303  21594.533546  68037.024
# some college       4707.0   84962.702227  24994.963474  29030.208
#
#                            25%            50%           75%           max
# education
# bachelors degree  85154.097000   98829.004800  115799.14680  159790.23450
# high school       39832.128000   46255.446000   53930.62080   78486.86520
# masters degree    98782.553760  113936.908800  131988.10416  175223.32190
# some college      68385.261696   84824.902426  103041.44640  149241.93034

# %%
# create visualization with multiple boxplots to show salary summary statistics by education level
plt.figure(figsize = (12,8))
ax = sns.boxplot(data=df, x = 'education', y = 'salary')
plt.xlabel("Education", fontsize = 14)
plt.ylabel("Salary", fontsize = 14)
plt.title("Salary Distrubution By Education Level", fontsize= 16)
# Out:
# Text(0.5, 1.0, 'Salary Distrubution By Education Level')

# %% [markdown]
# ##### Insights:
#
# Those with only a highschool level education make the lowest salary on average. The higher your education typically the higher your salary. There are some outlier towards the top of highschool.

# %% [markdown]
# ### Step 5 - Find Salary Summary Statistics by Gender

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by gender
df['salary'].groupby(df['gender']).describe()
# Out:
#           count           mean           std        min         25%  \
# gender
# Female  12730.0   98209.928810  24978.233860  28054.080  81938.1888
# Male    12709.0  104627.368954  26867.859585  29725.182  87625.1900
#
#                 50%          75%          max
# gender
# Female   98057.3880  115867.1844  163708.4064
# Male    104240.0788  123838.3008  175223.3219

# %%
# create visualization with multiple boxplots to show summary statistics by gender
plt.figure(figsize = (12,8))
ax = sns.boxplot(data = df, x = "gender", y = "salary")
plt.xlabel("Gender", fontsize = 14)
plt.ylabel("Salary", fontsize = 14)
plt.title("Distribution of Salary by Gender", fontsize= 16)
# Out:
# Text(0.5, 1.0, 'Distribution of Salary by Gender')

# %% [markdown]
# ##### Insights:
#
# Men typically have a higher salary than woman on average. The minimum and maximum are both lower for females than males.

# %% [markdown]
# ## Part 3 - Looking for Relationships in Data

# %% [markdown]
# ### Step 1 - Review Useful Tools for Bivariate Relationships

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in the blanks below with brief explanations of each type of plot listed
#
# - **Categorical Data**
# > ***Contingency Table***
# >
# > Summarize large data by category
# >
# > ***Clustered Bar Chart***
# >
# > Allows for comparison of series in a category.
#
# - **Mixed Data**
# > ***Individual Value Plot***
# >
# > Similar to a box plot make it easy to spot outliers and distribution spread
# >
# > ***Strip Plot***
# > Form of a scatter plot similar to a box plot
# >
#
# - **Quantitative Data**
# > ***Scatter plots***
# > Uses dots to represent values are used to observe relationships between variables
# >

# %% [markdown]
# ### Step 2 - Create Bivariate Plots & Tables

# %% [markdown]
# In the end of Part 2, you began looking at relationships between variables when you created boxplots which visualized the distribution of salary across different categories. In this step, you will make plots and visualizations to begin looking deeper for patterns and relationships between two variables.

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Use the Pandas Crosstab() function to compare categorical variables

# %% [markdown]
# #### crosstab of gender and education

# %%
# use pd.crosstab to count number of managers at each education level, grouped by gender
import pandas as pd
pd.crosstab(index=df['gender'], columns=df['education'])
# Out:
# education  bachelors degree  high school  masters degree  some college
# gender
# Female                 5468          387            4514          2361
# Male                   5504          394            4465          2346

# %% [markdown]
# ##### Insights:
#
# Females are more likely to continue their education after highschool

# %% [markdown]
# ### Strip plot between age and education

# %%
# create strip plot for age and education
plt.figure(figsize=(12,8))

ax = sns.stripplot(y=df['age'], x=df['education'])

# %% [markdown]
# ##### Insights:
#
# Those who are older are more likely to have a higher education level than highschool. More people have some form of higher education than just highschool.

# %% [markdown]
# ### Scatterplot for age and salary

# %%
# create scatterplot for age and salary
sns.scatterplot(x=df['age'], y=df['salary'])
# Out:
# <AxesSubplot: xlabel='age', ylabel='salary'>

# %% [markdown]
# ##### Insights:
#
# As you grow in age your salary also grows. From 50 to 60 you reach a peak of salary then drop back down the older you get.

# %% [markdown]
# ### Scatterplot for industry experience and salary

# %%
# create scatterplot for industry experience and salary
sns.scatterplot(x=df['industry_experience'], y=df['salary'])
# Out:
# <AxesSubplot: xlabel='industry_experience', ylabel='salary'>

# %% [markdown]
# ##### Insights:
#
# The more experience you have the higher your salary is. A little less than 15 years seems to be the minium of what is required to have the chance to start making a 140000 salary.

# %% [markdown]
# ### Step 3 - Pick Two More Bivariate Relationships to Visualize

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# create 1st visualization for bivariate relationship of your choice
sns.scatterplot(y=df['age'], x=df['industry_experience'])
# Out:
# <AxesSubplot: xlabel='industry_experience', ylabel='age'>

# %%
# create 2nd visualization for bivariate relationship of your choice
plt.figure(figsize=(12,8))

ax = sns.stripplot(y=df['industry_experience'], x=df['education'])

# %% [markdown]
# ## Part 4 - Correlation & Hypothesis Testing

# %% [markdown]
# ### Step 1 - Review Correlation

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with brief description of the following terms:
#
#
# - **Correlation**
# > ***Association between variables***
#
# - **Correlation Coefficient**
# >***A number between -1 and 1 that tells you the relationship between variables***

# %% [markdown]
# ### Step 2 - Review Hypothesis Testing & P-Value

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with brief description of the following terms:
#
# - **Hypothesis**
# > ***An assumption or statement that can be tested through scientific means***
#
# - **Null Hypothesis**
# > ***There is no relationship between variables***
#
# - **P-Value**
# > ***A value used to tell the significance of a correlation. A p-value of 0.05 or lower is generally considered statistically significant***

# %% [markdown]
# ### Step 3 - Use Pearsonr & Spearmanr To Answer Questions About Correlation and P-Values

# %% [markdown]
# <h3 style='color:red;'> First, load 'salary_numeric.csv' - where education has been re-expressed as numeric variables.</h3>

# %%
# load salary_numeric.csv into dataframe where education levels have been re-expressed as numeric

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# import pearson and spearmanr methods from scipy.stats library
from scipy.stats import pearsonr 
from scipy.stats import spearmanr

# %% [markdown]
# ### What is the correlation between salary and education?

# %% [markdown]
# #### Your Hypothesis = The higher your education the higher your salary

# %%
# calculate correlation and pvalue of salary and education with spearmanr method
spearmanr(df['salary'], df['education'])
# Out:
# SignificanceResult(statistic=-0.036094225294033305, pvalue=8.487428802115358e-09)

# %% [markdown]
# Salary tends to decrease slightly the higher your education is according to the negative correlation number.

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# These results are significant as the pvalue is extremely low

# %% [markdown]
# ### What is the correlation between salary and age?

# %% [markdown]
# #### Your Hypothesis = The older you are the higher your salary

# %%
# calculate correlation and pvalue of salary and age with pearsonr method
pearsonr(df['salary'], df['age'])
# Out:
# PearsonRResult(statistic=0.6631258539501879, pvalue=0.0)

# %% [markdown]
# Salary tends to increase the older you are

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# These result are significant as the p-value is less than 0.5

# %% [markdown]
# ### What is the correlation between salary and industry experience?

# %% [markdown]
# #### Your Hypothesis = The more experience you have the higher your salary

# %%
# calculate correlation and pvalue of salary and industry experience with pearsonr method
spearmanr(df['salary'], df['industry_experience'])
# Out:
# SignificanceResult(statistic=0.5910071254047617, pvalue=0.0)

# %% [markdown]
# Salary tends to increase the more experience you have

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# These result are significant as the p-value is less than 0.5

# %% [markdown]
# ### Step 4 - Report Findings

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### What was the null hypothesis for the relationships between education and salary, age and salary, and industry experience and salary?

# %% [markdown]
# education and salary
# - - There is no correlation between education and salary
# age and salary
# - - There is no correlation between age and salary
# industry experience and salary
# - - There is no correlation between experience and salary

# %% [markdown]
# ### Can you reject the null hypothesis for any of the relationships you explored above?

# %% [markdown]
# Yes

# %% [markdown]
# ## Part 5 - Multivariate Analysis

# %% [markdown]
# ### Step 1 - Review Types of Multivariate Analysis

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in the blanks with a brief description of each plot type
#
# - pairplots
# > takes all variables and compares them against each other
# - paired scatter plots
# > takes all variables and compares them against each other
# - correlation matrix
# > Shows the correlation between
# - heatmap
# > Shows the correlation between multiple variables and their relationships

# %% [markdown]
# ### Step 2 - Create Pairplots for Dataset

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### pairplot of whole dataframe

# %%
# create pairplot of dataframe
sns.pairplot(df)

# %% [markdown]
# ##### Insights:
#
# The older you are the more experience you have and higher salary you recieve.

# %% [markdown]
# ### Step 3 - Create Other Multivariate Plots

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Correlation matrix

# %%
# use .corr() to create correlation matrix
df.corr()
# Out:
# C:\Users\Ara\AppData\Local\Temp\ipykernel_12708\1038192848.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           age  industry_experience    salary
# age                  1.000000             0.842555  0.663126
# industry_experience  0.842555             1.000000  0.620691
# salary               0.663126             0.620691  1.000000

# %% [markdown]
# ### Heatmap of correlation matrix

# %%
# create heatmap visualization of correlation matrix
plt.figure(figsize=(12,8))

ax = sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')
# Out:
# C:\Users\Ara\AppData\Local\Temp\ipykernel_12708\669953756.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax = sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')

# %% [markdown]
# ##### Insights:
# Correlation between age and salary as well as experience and salary tend to be negative.

# %% [markdown]
# #### Crosstab of average salary grouped by education and industry

# %%
# use pd.crosstab() to calculate mean salary in each industry grouped by education level
pd.crosstab(index=df['industry'], columns=df['education'], values=df['salary'], aggfunc=np.mean).round(0)
# Out:
# education   bachelors degree  high school  masters degree  some college
# industry
# business             97618.0      46727.0        112037.0       81647.0
# finance             102401.0      48132.0        117568.0       85814.0
# healthcare           94149.0      44772.0        107954.0       80221.0
# technology          108436.0      51156.0        124632.0       92362.0

# %% [markdown]
# #### Heatmap of crosstab of average salary grouped by education and industry

# %%
# save above result to new variable
crosstab = pandas.crosstab(index=df['industry'], columns=df['education'], values=df['salary'], aggfunc=numpy.mean).round(0)
plt.figure(figsize=(16,10))

# %%
# create heatmap with annotated mean salary in each industry and education level
ax = sns.heatmap(crosstab, annot=True, linewidths=.5, cmap='YlGnBu', fmt='g', xticklabels=['High School', 'Some College', "Bachelor's Degree", "Master's Degree"])

plt.xlabel("Education Level", fontsize=14)
plt.ylabel("Industry", fontsize=14)

plt.title("Manager Salaries Across Industries by Education Level", fontsize=18);

# %% [markdown]
# ##### Insights:
#
# If you have a bachelor's degree and are in the technology industry you will get the highest salary.
# Having some college education gets you a lower salary than if you were to start working out of highschool. Having a master's doesn't always mean you'll make more money.

# %% [markdown]
# ### Step 4 - Report Findings

# %%
################################### TO DO #########################################
  
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ###### Along the way throughout this project, you should have been taking notes on insights from your exploratory data analysis. Take some time in a markdown cell below to write a couple paragraphs summarizing any observations, insights, conclusions, or further questions you have based on the exploratory analysis you conducted this week.

# %% [markdown]
# Why is it that those with some college seem to have the lowest salaries according to the heat map?

# %% [markdown]
# ### Step 5 - Submit Project

# %% [markdown]
# ###### Push to GitHub, record brief code review video, and share links with Tech Lead and SME.
